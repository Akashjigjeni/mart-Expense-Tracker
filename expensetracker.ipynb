# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("expense_data.csv")
print(df.head())
# Out:
#          date  category  amount
# 0  2026-04-01      Food     250
# 1  2026-04-01    Travel     100
# 2  2026-04-02  Shopping     500
# 3  2026-04-03      Food     300
# 4  2026-04-03     Bills     800

# %%
print("Total Expense:", df["amount"].sum())

print("\nExpense by Category:")
print(df.groupby("category")["amount"].sum())
# Out:
# Total Expense: 4050
#
# Expense by Category:
# category
# Bills            1500
# Entertainment     400
# Food              750
# Shopping         1150
# Travel            250
# Name: amount, dtype: int64

# %%
df.groupby("category")["amount"].sum().plot(kind='bar')
plt.title("Expenses by Category")
plt.xlabel("Category")
plt.ylabel("Amount")
plt.show()

# %%
df.groupby("category")["amount"].sum().plot(kind='pie', autopct='%1.1f%%')
plt.title("Expense Distribution")
plt.ylabel("")
plt.show()

# %%
df["date"] = pd.to_datetime(df["date"])
df.groupby("date")["amount"].sum().plot()
plt.title("Daily Expenses Trend")
plt.xlabel("Date")
plt.ylabel("Amount")
plt.show()
